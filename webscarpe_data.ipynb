# %%
import pandas as pd
import numpy as np

# %%
new_york = pd.read_csv('carsnyc.csv')
new_york['City'] = 'New York City'
new_york
# Out:
#                            Listing        Make  Year_model    Price   Milage  \
# 0          2013 INFINITI JX35 Base    INFINITI        2013  $13,888   73,953
# 1         2006 Suzuki Grand Vitara      Suzuki        2006   $3,995  121,390
# 2          2012 INFINITI FX50 Base    INFINITI        2012  $13,995  101,158
# 3          2012 Honda Odyssey EX-L       Honda        2012  $10,900   57,070
# 4          2012 INFINITI QX56 Base    INFINITI        2012  $13,495  137,301
# ...                            ...         ...         ...      ...      ...
# 3895   2018 Dodge Grand Caravan GT       Dodge        2018  $15,495   40,797
# 3896     2018 Chevrolet Impala 2LZ   Chevrolet        2018  $15,977   48,358
# 3897  2015 Mitsubishi Outlander SE  Mitsubishi        2015  $11,500   59,947
# 3898         2013 BMW 550 i xDrive         BMW        2013  $15,985   76,606
# 3899  2017 Toyota Highlander LE I4      Toyota        2017  $21,000   44,709
#
# ...

# %%
san_francisco = pd.read_csv('cars_sf.csv')
san_francisco['City'] = 'San Francisco'

# %%
chicago = pd.read_csv('cars_chi.csv')
chicago['City']='Chicago'

# %%
houston1 = pd.read_csv('cars_houston1-28.csv')
houston2 = pd.read_csv('cars29-50.csv')

# %%
houston = pd.concat([houston1,houston2])

houston["City"] = 'Houston'
houston = houston.reset_index(drop=True)
houston
# Out:
#                                       Listing           Make  Year_model  \
# 0     2009 Audi TTS 2.0T Premium Plus quattro           Audi        2009
# 1                    2012 Ford Focus Titanium           Ford        2012
# 2                   2020 Chevrolet Blazer 2LT      Chevrolet        2020
# 3             2003 Lincoln Town Car Signature        Lincoln        2003
# 4                   2007 Mercedes-Benz CL 550  Mercedes-Benz        2007
# ...                                       ...            ...         ...
# 4926                     2019 Nissan Sentra S         Nissan        2019
# 4927             2017 Cadillac XT5 Luxury FWD       Cadillac        2017
# 4928                    2016 Nissan Sentra SR         Nissan        2016
# 4929                 2015 Nissan Altima 2.5 S         Nissan        2015
# 4930                    2017 GMC Yukon Denali            GMC        2017
#
#         Price   Milage Exterior_color Interior_color Transmission Drivetrain  \
# ...

# %%
los_angeles = pd.read_csv('cars_la.csv')
los_angeles['City']= 'Los Angeles'
los_angeles
# Out:
#                                       Listing        Make  Year_model  \
# 0                              2009 Hummer H2      Hummer        2009
# 1                     2014 Jeep Patriot Sport        Jeep        2014
# 2           2019 RAM ProMaster 2500 High Roof         RAM        2019
# 3                 2014 Chevrolet Spark EV 1LT   Chevrolet        2014
# 4     2019 Volkswagen Arteon 2.0T SEL Premium  Volkswagen        2019
# ...                                       ...         ...         ...
# 4995          2017 FIAT 500e Battery Electric        FIAT        2017
# 4996                       2016 Honda CR-V EX       Honda        2016
# 4997                      2017 Ford Escape SE        Ford        2017
# 4998        2016 Ford Fusion Energi SE Luxury        Ford        2016
# 4999                    2015 Toyota Prius Two      Toyota        2015
#
#         Price   Milage Exterior_color Interior_color Transmission  \
# ...

# %%
seattle = pd.read_csv('cars_seattle.csv')
seattle['City'] = 'Seattle'
seattle
# Out:
#                                      Listing      Make  Year_model    Price  \
# 0      2015 Acura ILX 2.0L w/Premium Package     Acura        2015  $14,888
# 1                     2013 Hyundai Accent SE   Hyundai        2013   $6,888
# 2                  2015 Maserati Ghibli S Q4  Maserati        2015  $34,500
# 3             2017 Audi S7 4.0T Premium Plus      Audi        2017  $43,900
# 4                          2016 Lexus RX 350     Lexus        2016  $28,800
# ...                                      ...       ...         ...      ...
# 4995        2018 Toyota Prius Prime Advanced    Toyota        2018  $29,975
# 4996                     2014 Toyota Camry L    Toyota        2014   $9,988
# 4997  2015 Hyundai Santa Fe Sport 2.0L Turbo   Hyundai        2015  $14,987
# 4998        2018 Subaru Outback 2.5i Limited    Subaru        2018  $26,700
# 4999                  2008 Ford Explorer XLT      Ford        2008   $5,788
#
# ...

# %%
boston = pd.read_csv('cars_boston.csv')
boston['City'] = 'Boston'
boston
# Out:
#                                                 Listing        Make  \
# 0     2017 Volkswagen Golf TSI Wolfsburg Edition 4-Door  Volkswagen
# 1                             2016 Hyundai Tucson Sport     Hyundai
# 2                       2019 Honda Civic Type R Touring       Honda
# 3                                    2012 FIAT 500C Pop        FIAT
# 4                           2014 Chevrolet Spark EV 2LT   Chevrolet
# ...                                                 ...         ...
# 4995                   2017 Chevrolet Silverado 1500 LT   Chevrolet
# 4996                             2014 Ford Explorer XLT        Ford
# 4997                               2016 Honda Accord LX       Honda
# 4998                             2011 Toyota Venza Base      Toyota
# 4999                    2017 Jeep Patriot High Altitude        Jeep
#
#       Year_model    Price  Milage Exterior_color Interior_color Transmission  \
# ...

# %%
princton = pd.read_csv('cars_nj.csv')
princton['City']='Princeton'
princton
# Out:
#                                         Listing        Make  Year_model  \
# 0                             2019 Lexus UX 200       Lexus        2019
# 1                        2008 INFINITI M35 Base    INFINITI        2008
# 2     2018 Volkswagen Atlas 3.6L Launch Edition  Volkswagen        2018
# 3                 2017 Volkswagen CC 2.0T Sport  Volkswagen        2017
# 4                   2015 Hyundai Sonata Limited     Hyundai        2015
# ...                                         ...         ...         ...
# 4988                      2016 Honda Odyssey LX       Honda        2016
# 4989                   2019 Lexus GX 460 Luxury       Lexus        2019
# 4990                    2010 INFINITI FX35 Base    INFINITI        2010
# 4991                    2019 INFINITI QX80 Luxe    INFINITI        2019
# 4992               2019 Land Rover Discovery SE        Land        2019
#
#            Price   Milage Exterior_color Interior_color Transmission  \
# ...

# %%
miami = pd.read_csv('cars_miami.csv')
miami['City']='Miami'
miami
# Out:
#                                   Listing        Make  Year_model    Price  \
# 0     2016 Hyundai Genesis Coupe 3.8 Base     Hyundai        2016  $14,785
# 1        2016 Hyundai Santa Fe Sport 2.4L     Hyundai        2016   $9,991
# 2      2015 Mitsubishi Outlander Sport ES  Mitsubishi        2015   $6,991
# 3                   2013 Dodge Avenger SE       Dodge        2013   $3,991
# 4                  2015 Cadillac ATS 2.5L    Cadillac        2015   $9,691
# ...                                   ...         ...         ...      ...
# 4995                  2016 Nissan Juke SL      Nissan        2016  $15,446
# 4996                  2017 Ford Escape SE        Ford        2017  $13,990
# 4997     2019 Volkswagen Atlas 3.6L V6 SE  Volkswagen        2019  $25,950
# 4998           2015 Chevrolet Equinox 1LT   Chevrolet        2015   $6,590
# 4999                 2019 Toyota RAV4 XLE      Toyota        2019  $20,637
#
# ...

# %%
cars_df = pd.concat([new_york,san_francisco, chicago, houston,los_angeles,seattle, boston, miami])
cars_df = cars_df.reset_index(drop=True)
cars_df
# Out:
#                                 Listing        Make  Year_model    Price  \
# 0               2013 INFINITI JX35 Base    INFINITI        2013  $13,888
# 1              2006 Suzuki Grand Vitara      Suzuki        2006   $3,995
# 2               2012 INFINITI FX50 Base    INFINITI        2012  $13,995
# 3               2012 Honda Odyssey EX-L       Honda        2012  $10,900
# 4               2012 INFINITI QX56 Base    INFINITI        2012  $13,495
# ...                                 ...         ...         ...      ...
# 38626               2016 Nissan Juke SL      Nissan        2016  $15,446
# 38627               2017 Ford Escape SE        Ford        2017  $13,990
# 38628  2019 Volkswagen Atlas 3.6L V6 SE  Volkswagen        2019  $25,950
# 38629        2015 Chevrolet Equinox 1LT   Chevrolet        2015   $6,590
# 38630              2019 Toyota RAV4 XLE      Toyota        2019  $20,637
#
#         Milage Exterior_color Interior_color Transmission         Drivetrain  \
# ...

# %%
cars_df.Make.unique()
cars_df2 = cars_df.copy()
cars_df2.Make.replace(['Land','Aston'],['Land Rover','Aston Martin'],inplace= True)
cars_df2.Make.unique()
cars_df.Make.replace(['Land','Aston'],['Land Rover','Aston Martin'],inplace= True)

# %%
cars_df
# Out:
#                                 Listing        Make  Year_model    Price  \
# 0               2013 INFINITI JX35 Base    INFINITI        2013  $13,888
# 1              2006 Suzuki Grand Vitara      Suzuki        2006   $3,995
# 2               2012 INFINITI FX50 Base    INFINITI        2012  $13,995
# 3               2012 Honda Odyssey EX-L       Honda        2012  $10,900
# 4               2012 INFINITI QX56 Base    INFINITI        2012  $13,495
# ...                                 ...         ...         ...      ...
# 38626               2016 Nissan Juke SL      Nissan        2016  $15,446
# 38627               2017 Ford Escape SE        Ford        2017  $13,990
# 38628  2019 Volkswagen Atlas 3.6L V6 SE  Volkswagen        2019  $25,950
# 38629        2015 Chevrolet Equinox 1LT   Chevrolet        2015   $6,590
# 38630              2019 Toyota RAV4 XLE      Toyota        2019  $20,637
#
#         Milage Exterior_color Interior_color Transmission         Drivetrain  \
# ...

# %%
from matplotlib import pyplot as plt
plt.style.use('ggplot')
import re
import string

# %%
x =cars_df.iloc[0,4]
#filter(lambda t: t.isdigit(),x
int(re.sub("\D","",x))
# Out:
# 73953

# %%
x =cars_df.iloc[0,3]
#filter(lambda t: t.isdigit(),x
float(re.sub("\D","",x))
# Out:
# 13888.0

# %%
cars_df2['Milage'] =cars_df2.Milage.apply(lambda x: re.sub('\D','',x))

cars_df2['Price'] = cars_df2.Price.apply(lambda x: re.sub('\D','',x))
cars_df2
# Out:
#                                 Listing        Make  Year_model  Price  \
# 0               2013 INFINITI JX35 Base    INFINITI        2013  13888
# 1              2006 Suzuki Grand Vitara      Suzuki        2006   3995
# 2               2012 INFINITI FX50 Base    INFINITI        2012  13995
# 3               2012 Honda Odyssey EX-L       Honda        2012  10900
# 4               2012 INFINITI QX56 Base    INFINITI        2012  13495
# ...                                 ...         ...         ...    ...
# 38626               2016 Nissan Juke SL      Nissan        2016  15446
# 38627               2017 Ford Escape SE        Ford        2017  13990
# 38628  2019 Volkswagen Atlas 3.6L V6 SE  Volkswagen        2019  25950
# 38629        2015 Chevrolet Equinox 1LT   Chevrolet        2015   6590
# 38630              2019 Toyota RAV4 XLE      Toyota        2019  20637
#
#        Milage Exterior_color Interior_color Transmission         Drivetrain  \
# ...

# %%
pd.to_numeric(cars_df2.Milage)
# Out:
# 0         73953.0
# 1        121390.0
# 2        101158.0
# 3         57070.0
# 4        137301.0
#            ...
# 38626     49293.0
# 38627     31252.0
# 38628     15349.0
# 38629    140410.0
# 38630     24206.0
# Name: Milage, Length: 38631, dtype: float64

# %%
cars_df2['Milage'] = pd.to_numeric(cars_df2.Milage)

# %%
cars_df2['Price'] = pd.to_numeric(cars_df2.Price)

# %%
cars_df2.Price.max()
# Out:
# 60000

# %%
cars_df2['Price'] = cars_df2['Price'].astype(float)

# %%
cars_df2
# Out:
#                                 Listing        Make  Year_model    Price  \
# 0               2013 INFINITI JX35 Base    INFINITI        2013  13888.0
# 1              2006 Suzuki Grand Vitara      Suzuki        2006   3995.0
# 2               2012 INFINITI FX50 Base    INFINITI        2012  13995.0
# 3               2012 Honda Odyssey EX-L       Honda        2012  10900.0
# 4               2012 INFINITI QX56 Base    INFINITI        2012  13495.0
# ...                                 ...         ...         ...      ...
# 38626               2016 Nissan Juke SL      Nissan        2016  15446.0
# 38627               2017 Ford Escape SE        Ford        2017  13990.0
# 38628  2019 Volkswagen Atlas 3.6L V6 SE  Volkswagen        2019  25950.0
# 38629        2015 Chevrolet Equinox 1LT   Chevrolet        2015   6590.0
# 38630              2019 Toyota RAV4 XLE      Toyota        2019  20637.0
#
#          Milage Exterior_color Interior_color Transmission         Drivetrain  \
# ...

# %%
cars_df2.to_csv('cars_df.csv',index = False)

# %%
test = pd.read_csv('cars_df.csv')

# %%
test
# Out:
#                                 Listing        Make  Year_model    Price  \
# 0               2013 INFINITI JX35 Base    INFINITI        2013  13888.0
# 1              2006 Suzuki Grand Vitara      Suzuki        2006   3995.0
# 2               2012 INFINITI FX50 Base    INFINITI        2012  13995.0
# 3               2012 Honda Odyssey EX-L       Honda        2012  10900.0
# 4               2012 INFINITI QX56 Base    INFINITI        2012  13495.0
# ...                                 ...         ...         ...      ...
# 38626               2016 Nissan Juke SL      Nissan        2016  15446.0
# 38627               2017 Ford Escape SE        Ford        2017  13990.0
# 38628  2019 Volkswagen Atlas 3.6L V6 SE  Volkswagen        2019  25950.0
# 38629        2015 Chevrolet Equinox 1LT   Chevrolet        2015   6590.0
# 38630              2019 Toyota RAV4 XLE      Toyota        2019  20637.0
#
#          Milage Exterior_color Interior_color Transmission         Drivetrain  \
# ...
